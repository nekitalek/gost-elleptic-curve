# %%
import random

def CheckForDesc(D):
    if D % 8 == 1 and D % 3 != 0:
        return 1
    else:
        return 0

def ChoosingD():
    for i in range(-11000000, -1000000):
        if CheckForDesc(i) == 1:
            return i
        

def CheckForMod4(D):
    if D % 4 == 1:
        print("Success")
    else:
        print("failed")
        
def is_prime(n):
    for i in range(2,int(n/2)):
        if (n%i) == 0:
              return False
    return True

def GenerateAB(D):
    D *= -1 
    while (1):
        a = random.randint(100000000000000000, 99999999999999999999999999999999999999999)
        b = random.randint(100000000000000000, 99999999999999999999999999999999999999999)
        p = ((D + 1)/4) * (a*a) + (D * a * b) + (D * (b*b))
        print("p = ", p)
        if (is_prime(p) == True):
            c = 3
            N = (p + 1 + a)/c
            if (N > 2**252):
                print("a = ", a )
                print("b = ", b )
                
    
#D = -10999999
D = ChoosingD()
K = QuadraticField(D)
H_d = K.class_number()
print("D =", D)
print("H_d = ", H_d)
CheckForMod4(D)
GenerateAB(D)
# Out:
# D = -10999999
# H_d =  3094
# Success
# p =  102786643090145151407738340301109717567787856782897037116977566487403416969617069631885464
# p =  49410046221096533553522525990165861371746111288717774712731811853977983056758073498783095
# p =  16050763718584309260282380740993932016684946373642711539378630341672002870540926368238633
# p =  35581875900764042624884772207784223337854521241358253150213080070296103949362720584155256
# p =  80510667694429954899807692875448483680089655515101592993317156675236461831896171406919291
# p =  42298814917234661232009632635994158563565406003635531891399893798642330064104389431196800
# p =  80600614042902112424486358952158619683073914256452149548856305694834562677974305366450556
# p =  229958865905412719180997212668297330137561088843993521918355568261786917181343057410975442
# p =  71840555447052218327065117728692967802042652644441667249151438167957199217613743351017043
# ...
